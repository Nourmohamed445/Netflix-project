# %%
import pandas as pd

# %%
# importing the data set
data = pd.read_csv("netflix_dataset.csv")

# %%
# get the first 5 items 
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# get the last 5 items 
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
# to know the shape of it
data.shape
# Out:
# (7789, 11)

# %%
# to know the size
data.size
# Out:
# 85679

# %%
# to kmow the columns name 
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# to know the data type of your series 
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
# first check the duplicated items 
data.duplicated().value_counts()
# Out:
# False    7787
# True        2
# Name: count, dtype: int64

# %%
# there is two duplicated values .. to sees the two duplicated rows 
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# get the data size before and after removing the duplicated rows
data.size
# Out:
# 85679

# %%
# now we are removiung it 
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (7787, 11)

# %%
# check again 
data.duplicated().value_counts()
# Out:
# False    7787
# Name: count, dtype: int64

# %%
# Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
# check if there is null values 
data.isna().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# now we import seaborn for using heatmap
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
data[data['Title'] == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# here we get the show id 
data[data['Title'] == 'House of Cards']['Show_Id']
# Out:
# 2832    s2833
# Name: Show_Id, dtype: object

# %%
# here we get the movie director 
data[data['Title'] == 'House of Cards']['Director']
# Out:
# 2832    Robin Wright, David Fincher, Gerald McRaney, J...
# Name: Director, dtype: object

# %%
# Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
# we will create a new column call it Date and we will make it from datetime type
data['Date'] = pd.to_datetime(data["Release_Date"], format='mixed')

# %%
data.head(50)
# now we can see we added the new column
# Out:
#    Show_Id Category                                Title  \
# 0       s1  TV Show                                   3%
# 1       s2    Movie                                07:19
# 2       s3    Movie                                23:59
# 3       s4    Movie                                    9
# 4       s5    Movie                                   21
# 5       s6  TV Show                                   46
# 6       s7    Movie                                  122
# 7       s8    Movie                                  187
# 8       s9    Movie                                  706
# 9      s10    Movie                                 1920
# 10     s11    Movie                                 1922
# 11     s12  TV Show                                 1983
# 12     s13  TV Show                                 1994
# 13     s14    Movie                                2,215
# 14     s15    Movie                                 3022
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date            datetime64[ns]
# dtype: object

# %%
data.Date.dt.year.value_counts()
# Out:
# Date
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data.Date.dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
# Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data.head(10)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
# Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# after we got the count of the movies and tv-shows 
# we show it by bar-plot
sns.countplot(x=data["Category"])
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
# Q. 4) Show all the Movies that were released in year 2000.

# %%
# first create a year column 
data['Year'] = data.Date.dt.year

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
# now to get the all movies realsed in 2000 
data[(data.Category == 'Movie') & (data.Year == 2000.0)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date, Year]
# Index: []

# %%
# other way to solve it 
data[(data.Category == 'Movie') & (data.Date.dt.year == 2000.0)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date, Year]
# Index: []

# %%
# both answers show we dont have a movies realsed in year 2000

# %%
# Q. 5) Show only the Titles of all TV Shows that were released in India only

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
# now we get the all rows has tv-shows and india
india_tv_shows =  data[(data.Category == "TV Show" ) & (data.Country == "India")]
india_tv_shows
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country  \
# ...

# %%
# now we get the title of all of these 
india_tv_shows.Title.values
# Out:
# array(['21 Sarfarosh: Saragarhi 1897', '7 (Seven)', 'Agent Raghav',
#        'Akbar\xa0Birbal', 'Anjaan: Rural Myths',
#        'Anjaan: Special Crimes Unit', 'Bad Boy Billionaires: India',
#        'Badalte Rishton Ki Dastaan', 'Bard of Blood', 'Betaal',
#        'Bh Se Bhade', 'Bhaag Beanie Bhaag', 'Bhaage Re Mann',
#        'Chhota Bheem', 'ChuChu TV Nursery Rhymes & Kids Songs (Hindi)',
#        'Classic Legends', 'College Romance',
#        'Cricket Fever: Mumbai Indians', 'Darr Sabko Lagta Hai',
#        'Delhi Crime', 'Devlok with Devdutt Pattanaik', 'Dharmakshetra',
#        'Engineering Girls', 'Fabulous Lives of Bollywood Wives',
#        'Fear Files... Har Mod Pe Darr', 'Gabru: Hip Hop Revolution',
#        'Gangs of Hassepur', 'GHOUL', 'Girls Hostel', 'Hasmukh', 'Inmates',
#        'Jamtara - Sabka Number Ayega', 'Jhansi Ki Rani',
#        'Khan: No. 1 Crime Hunter', 'Khelti Hai Zindagi Aankh Micholi',
#        'Khotey Sikkey', 'Ladies Up', 'Leila', 'Little Singham',
# ...

# %%
# Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description       Date    Year
# ...

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
# Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
data[(data.Category == 'Movie') & ((data.Type == "Comedies") | (data.Country == "United Kingdom"))].head(10)
# Out:
#     Show_Id Category                                   Title  \
# 19      s20    Movie                                     '89
# 33      s34    Movie                            #realityhigh
# 72      s73    Movie                                17 Again
# 82      s83    Movie                     2036 Origin Unknown
# 84      s85    Movie                               21 & Over
# 93      s94    Movie                       27: Gone Too Soon
# 148    s149    Movie                    A Bad Moms Christmas
# 174    s175    Movie             A Futile and Stupid Gesture
# 181    s182    Movie  A Grand Night In: The Story of Aardman
# 196    s197    Movie                          A Little Chaos
#
#                    Director  \
# 19                      NaN
# 33         Fernando Lebrija
# 72              Burr Steers
# 82            Hasraf Dulull
# 84   Jon Lucas, Scott Moore
# 93        Simon Napier-Bell
# 148  Jon Lucas, Scott Moore
# 174              David Wain
# ...

# %%
# Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[data.Cast == "Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date, Year]
# Index: []

# %%
data.dropna(inplace=True)

# %%
data[data.Cast.str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       Date    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
# Q. 9) What are the different Ratings defined by Netflix ?

# %%
# the ratings 
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       Date    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
# the unique ratings 
data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# the nunique value
data.Rating.nunique()
# Out:
# 14

# %%
# Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       Date    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
data[(data['Category']=="Movie") & (data['Rating'] == 'TV-14' )]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
data[(data['Category']=="Movie") & (data['Rating'] == 'TV-14' ) & (data['Country']== "Canada")].shape
# Out:
# (9, 13)

# %%
# Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
data[(data['Category']=="TV Shows") & (data['Rating'] == 'R' ) & (data['Year'] > 2018.0 )].shape
# Out:
# (0, 13)

# %%
# Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description       Date    Year
# ...

# %%
data[["Time","Unites"]] = data['Duration'].str.split(" ",expand=True)
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       Date    Year Time  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0   93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0   78
#
#   Unites
# 1    min
# 2    min

# %%
data['Time'].max()
# Out:
# '99'
